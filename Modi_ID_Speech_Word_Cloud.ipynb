# %%
import pandas as pd
import numpy as np

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import json

# %%
url = 'https://www.news18.com/news/india/pm-modis-88-minute-long-independence-day-speech-from-ramparts-of-red-fort-full-text-here-4088603.html'
html = requests.get(url)
soup = BeautifulSoup(html.content, features="html.parser")

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)

print(text)
# Out:
# PM Modi's 88-Minute-Long Independence Day Speech from Ramparts of Red Fort: Full Text HereCHANGE LANGUAGEEnglish हिन्दी বাংলা मराठी ગુજરાતી ಕನ್ನಡ தமிழ் മലയാളം తెలుగు ਪੰਜਾਬੀ اردو অসমীয়া ଓଡ଼ିଆ WATCH LIVE TVDOWNLOAD News18 APPFollow Us OnTrending Topics :#BiggBossOTT#Coronavirus#Afghanistan#IndvsEng#IndependenceDayHomeCoronavirusPoliticsIndiaEntertainmentTechAutoBuzzOpinionVideosPhotosTrackerHomeCoronavirusPoliticsIndiaEntertainmentTechAutoBuzzOpinionVideosPhotosBusinessWorldEducation and CareerAstrologyHealthLifestyleSportsPodcastTravelFootballFoodCricketNext TennisExplainersPolitical WhispersInfluential Leaders of New IndiaBYJU’S Young GeniusLatestLifestyleMoviesBigg Boss OTTCricketBusinessEducation-CareerExplainersIndia PositiveInfluential Leaders of New IndiaLatestLifestyleMoviesBigg Boss OTTCricketBusinessEducation-CareerExplainersIndia PositiveInfluential Leaders of New IndiaHome »
# News »
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
stop_words = ["scheme","goal","resolution","going","need","resolve","move","say","give","effort","great","forward","change","made","Indian","PM Modi","PM","Modi","Independence Day","Independence","Day","crore","made","work","freedom","country", "India", "Today","New","Time","will","government","now","world","every","year","people","dear","years","brothers","sisters","make","mother","nation","one","whether","want","take","us","therefore","come","together","Prime" ,"Minister","Countrymen"] + list(STOPWORDS)
wordcloud = WordCloud(stopwords=stop_words, background_color="white").generate(text)
plt.figure( figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
url = 'https://www.indiatoday.in/india/story/narendra-modi-independence-day-speech-full-text-red-fort-204216-2014-08-15'
html = requests.get(url)
soup = BeautifulSoup(html.content, features="html.parser")

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)

print(text)
# Out:
# Modi's first Independence Day speech: Full text - India News
# Jump to navigation
# IndiaTodayMalayalamBusiness TodayDailyOAaj TakLallantopiChowkReader’s DigestNewsLIVE TV APPMagazine
# Login Home MY FEED Olympics 2020 India
# World
# Business
# Tech Movies
# Sports
# Science Health Videos
# Corona Education Malayalam Fact Check
# Visual Stories Quiz Gaming DIU NewsMo
# Cities
# Trending Binge Watch
# Auto
# Lifestyle
# Television
# AQI CODE OF ETHICS Rate Card Dark Mode
# Speak Now Listening Re SpeakSubmitxNewsIndiaNarendra Modi's first Independence Day speech: Full text
# Narendra Modi's first Independence Day speech: Full textPrime Minister addressed the nation from Red Fort on the 68th Independence Day in an hour-long extempore speechadvertisement
# india today digital
# New DelhiAugust 15, 2014UPDATED: September 17, 2016 09:52 IST
# ...

# %%
stop_words = ["scheme","goal","resolution","going","need","resolve","move","say","give","effort","great","forward","change","made","Indian","PM Modi","PM","Modi","Independence Day","Independence","Day","crore","made","work","freedom","country", "India", "Today","New","Time","will","government","now","world","every","year","people","dear","years","brothers","sisters","make","mother","nation","one","whether","want","take","us","therefore","come","together","Prime" ,"Minister","Countrymen"] + list(STOPWORDS)
wordcloud = WordCloud(stopwords=stop_words, background_color="white").generate(text)
plt.figure( figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
